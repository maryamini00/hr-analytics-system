# %% [markdown]
# ### import libraries

# %%
import numpy as np
import pandas as pd 
from faker import Faker as fk 
import matplotlib.pyplot as plt
import random
from datetime import datetime, timedelta
from scipy.stats import truncnorm

fake = fk("fa_IR")
number_of_employees = 450 # without ceo

# %% [markdown]
# ## Basic personal information

# %% [markdown]
# #### national_code = 03 + 7/8 + 7 ranom number

# %%
d = pd.DataFrame({
    "n1": "03",
    "n2": np.random.choice([7, 8], size = number_of_employees).astype(str),
    "n3": np.random.randint(1000000, 10000000, size = number_of_employees).astype(str)
})

d["national_code"] = d["n1"] + d["n2"] + d["n3"]
d = d.drop(["n1", "n2", "n3"], axis=1)

# %% [markdown]
# #### phone number = 09 + 9 random number

# %%
d["n1"] = "09"
d["n2"] = np.random.choice(["12", "19", "10"], size = number_of_employees)
d["n3"] = np.random.randint(1000000, 10000000, size = number_of_employees).astype(str)
d["phone_number"] = d["n1"] + d["n2"] + d["n3"]
d = d.drop(["n1", "n2", "n3"], axis=1)

# %% [markdown]
# #### emergency contact   phone + name

# %%
d["n1"] = "09"
d["n2"] = np.random.choice(["12", "19", "10"], size = number_of_employees)
d["n3"] = np.random.randint(1000000, 10000000, size = number_of_employees).astype(str)
d_ecn = [{
    "emergency_contact_name": fake.name()
}
    for _ in range(number_of_employees)]
d["emergency_contact_phone"] = d["n1"] + d["n2"] + d["n3"]
d = d.drop(["n1", "n2", "n3"], axis=1)
    
d_1 = pd.DataFrame(d_ecn)
d = pd.concat([d, d_1], axis=1)

# %% [markdown]
# #### first name / last name / father name / gender / email

# %%
d_f = [{
    "first_name": fake.first_name_female(),
    "last_name": fake.last_name(),
    "gender": "خانم",
    "father_name": fake.first_name_male(),
    "email": fake.company_email()
}
    for _ in range(int(number_of_employees * 0.35))]
d_m = [{
    "first_name": fake.first_name_male(),
    "last_name": fake.last_name(),
    "gender": "آقا",
    "father_name": fake.first_name_male(),
    "email": fake.company_email()
}
    for _ in range(int(number_of_employees * 0.65))]
d_s = d_f + d_m
d_s = pd.DataFrame(d_s)
d = pd.concat([d, d_s], axis=1)

# %% [markdown]
# #### address

# %%
d_s = [{
    "address": fake.street_address(),
}
    for _ in range(number_of_employees)]
d["address"] = pd.DataFrame(d_s)

# %% [markdown]
# #### position / department

# %%
dep_num_pos = {
    "مدیر ارشد حقوقی": 1,
    
    "مدیر دپارتمان دعاوی": 1,
    "مدیر دپارتمان شرکت ها": 1,
    "مدیر دپارتمان قراردداد ها": 1,
    "مدیر دپارتمان مالکیت فکری": 1,
    "مدیر دپارتمان تطبیق و انطباق": 1,
    "مدیر دپارتمان حقوق کار ": 1,
    "مدیر دپارتمان حقوق مالیاتی": 1,
    "مدیر دپارتمان تحقیقات حقوقی": 1,
    
    "وکیل ارشد": 12,
    "وکیل": 32,
    "وکیل جوان": 20,
    "دستیار حقوقی - دعاوی": 10,
    "کارشناسی پرونده": 11,
    
    "وکیل ارشد شرکتی": 6,
    "وکیل شرکتی": 15,
    "مشاور حقوقی - امور شرکتی ": 8,
    "دستیار حقوقی - امور شرکتی": 5,
    
    "متخصص ارشد قرارداد ها": 5,
    "متخصص قرارداد ها": 14,
    "بازبین قرارداد ها": 8,
    "دستیار حقوقی - قرارداد ها": 5,
    
    "وکیل ثبت اختراع": 4,
    "وکیل علائم تجاری": 4,
    "متخصص مالکیت فکری": 6,
    "دستیار حقوقی - ماللکیت فکری": 4,
    
    "افسر انطباق": 10,
    "تحلیلگر ریسک": 6,
    "متخصص مقررات": 5,
    "حسابرس": 5,
    
    "وکیل ارشد کار": 3,
    "وکیل کار": 8,
    "مشاور حقوقی منابع انسانی": 4,
    "دستیار حقوقی - کار و اشتغال": 3,
    
    "وکیل ارشد مالیاتی": 3,
    "وکیل مالیاتی": 7,
    "مشاور مالیاتی": 5,
    "دستیار حقوقی - مالیات": 3,
    
    "پژوهشگر ارشد حقوقی": 3,
    "پژوهشگر حقوقی": 8,
    "متخصص مستندسازی": 4,
    "کتابدار": 2,
    
    "مدیر دپارتمان مالی": 1,
    "مدیر ارشد مالی": 1,
    "مدیر حسابداری": 1,
    "حسابدار ارشد": 4,
    "حسابدار": 10,
    "دستیار حسابداری": 4,
    "مدیر حقوق و دستمزد": 1,
    "متخصص حقوق و دستمزد": 4,
    "کارمند حقوق و دستمزد": 2,
    "مدیر برنامه ریزی مالی": 1,
    "تحلیلگر مالی": 7,
    "تحلیلگر بودجه": 5,
    
    "مدیر دپارتمان منابع انسانی": 1,
    "مدیر منابع انسانی": 1,
    "مدیر جذب و استخدام": 1,
    "کارشناس استخدام": 8,
    "متخصص جذب استعداد": 4,
    "مدیر عملیات منابع انسانی": 1,
    "متخصص منابع انسانی": 8,
    "هماهنگ‌کننده منابع انسانی": 5,
    "مدیر آموزش": 1,
    "مربی": 4,
    "متخصص یادگیری": 3,
    
    "مدیر دپارتمان فناوری اطلاعات": 1,
    "مدیر فناوری اطلاعات": 1,
    "مدیر زیرساخت": 1,
    "مدیر سیستم": 5,
    "مهندس شبکه": 4,
    "متخصص پشتیبانی فنی": 8,
    "مدیر نرم‌افزار": 1,
    "توسعه‌دهنده بک‌اند": 8,
    "توسعه‌دهنده فرانت‌اند": 5,
    "مهندس تضمین کیفیت": 5,
    "مدیر پایگاه داده": 2,
    "مدیر امنیت": 1,
    "تحلیلگر امنیت": 4,
    "متخصص مرکز عملیات امنیت": 3,
    
    "مدیر دپارتمان اداری": 1,
    "مدیر اداری": 1,
    "مدیر دفتر": 2,
    "دستیار اجرایی": 5,
    "منشی": 6,
    "کارشناس تدارکات": 6,
    "کارمند اداری": 8,
    
    "مدیر دپارتمان توسعه کسب و کار": 1,
    "مدیر توسعه کسب‌وکار": 1,
    "سرپرست توسعه کسب‌وکار": 2,
    "متخصص بازاریابی": 7,
    "متخصص فروش": 8,
    "متخصص مدیریت ارتباط با مشتری": 4,
    
    "مدیر دپارتمان حسابرسی داخلی": 1,
    "مدیر حسابرسی": 1,
    "حسابرس داخلی": 5,
    "حسابرس انطباق": 4,
    "افسر ریسک": 3,
}

dep_pos = {
    "اداره امور حقوقی": [
        "مدیر ارشد حقوقی",
        "مدیر دپارتمان دعاوی",
        "مدیر دپارتمان شرکت ها",
        "مدیر دپارتمان قراردداد ها",
        "مدیر دپارتمان مالکیت فکری",
        "مدیر دپارتمان تطبیق و انطباق",
        "مدیر دپارتمان حقوق کار ",
        "مدیر دپارتمان حقوق مالیاتی",
        "مدیر دپارتمان تحقیقات حقوقی",
    ],

    "دعاوی": [
        "وکیل ارشد",
        "وکیل",
        "وکیل جوان",
        "دستیار حقوقی - دعاوی",
        "کارشناسی پرونده",
    ],

    "امور شرکتی": [
        "وکیل ارشد شرکتی",
        "وکیل شرکتی",
        "مشاور حقوقی - امور شرکتی ",
        "دستیار حقوقی - امور شرکتی",
    ],

    "قرارداد ها": [
        "متخصص ارشد قرارداد ها",
        "متخصص قرارداد ها",
        "بازبین قرارداد ها",
        "دستیار حقوقی - قرارداد ها",
    ],

    "مالکیت فکری": [
        "وکیل ثبت اختراع",
        "وکیل علائم تجاری",
        "متخصص مالکیت فکری",
        "دستیار حقوقی - ماللکیت فکری",
    ],

    "انطباق و تطبیق": [
        "افسر انطباق",
        "تحلیلگر ریسک",
        "متخصص مقررات",
        "حسابرس",
    ],

    "کار و اشتغال": [
        "وکیل ارشد کار",
        "وکیل کار",
        "مشاور حقوقی منابع انسانی",
        "دستیار حقوقی - کار و اشتغال",
    ],

    "مالیات": [
        "وکیل ارشد مالیاتی",
        "وکیل مالیاتی",
        "مشاور مالیاتی",
        "دستیار حقوقی - مالیات",
    ],

    "پژوهش حقوقی": [
        "پژوهشگر ارشد حقوقی",
        "پژوهشگر حقوقی",
        "متخصص مستندسازی",
        "کتابدار",
    ],

    "امور مالی": [
        "مدیر دپارتمان مالی",
        "مدیر ارشد مالی",
        "مدیر حسابداری",
        "حسابدار ارشد",
        "حسابدار",
        "دستیار حسابداری",
        "مدیر حقوق و دستمزد",
        "متخصص حقوق و دستمزد",
        "کارمند حقوق و دستمزد",
        "مدیر برنامه ریزی مالی",
        "تحلیلگر مالی",
        "تحلیلگر بودجه",
    ],

    "منابع انسانی": [
        "مدیر دپارتمان منابع انسانی",
        "مدیر منابع انسانی",
        "مدیر جذب و استخدام",
        "کارشناس استخدام",
        "متخصص جذب استعداد",
        "مدیر عملیات منابع انسانی",
        "متخصص منابع انسانی",
        "هماهنگ‌کننده منابع انسانی",
        "مدیر آموزش",
        "مربی",
        "متخصص یادگیری",
    ],

    "فناوری اطلاعات": [
        "مدیر دپارتمان فناوری اطلاعات",
        "مدیر فناوری اطلاعات",
        "مدیر زیرساخت",
        "مدیر سیستم",
        "مهندس شبکه",
        "متخصص پشتیبانی فنی",
        "مدیر نرم‌افزار",
        "توسعه‌دهنده بک‌اند",
        "توسعه‌دهنده فرانت‌اند",
        "مهندس تضمین کیفیت",
        "مدیر پایگاه داده",
        "مدیر امنیت",
        "تحلیلگر امنیت",
        "متخصص مرکز عملیات امنیت",
    ],

    "اداری": [
        "مدیر دپارتمان اداری",
        "مدیر اداری",
        "مدیر دفتر",
        "دستیار اجرایی",
        "منشی",
        "کارشناس تدارکات",
        "کارمند اداری",
    ],

    "توسعه کسب و کار": [
        "مدیر دپارتمان توسعه کسب و کار",
        "مدیر توسعه کسب‌وکار",
        "سرپرست توسعه کسب‌وکار",
        "متخصص بازاریابی",
        "متخصص فروش",
        "متخصص مدیریت ارتباط با مشتری",
    ],

    "حسابرسی داخلی": [
        "مدیر دپارتمان حسابرسی داخلی",
        "مدیر حسابرسی",
        "حسابرس داخلی",
        "حسابرس انطباق",
        "افسر ریسک",
    ],
}

position = []
department = []

for dep, pos_list in dep_pos.items():
    for pos in pos_list:
        count = dep_num_pos[pos]
        position.extend([pos] * count)
        department.extend([dep] * count)

assert len(position) == number_of_employees
assert len(department) == number_of_employees

d["position"] = position
d["department"] = department

# %% [markdown]
# #### create CEO

# %%
ceo_dic = {
    "national_code": "0362528876",
    "phone_number": "091277594481",
    "emergency_contact_phone": "09960857522",
    "emergency_contact_name": "منا محمدی",
    "first_name": "مریم",
    "last_name": "امینی خواه",
    "gender": "خانم",
    "father_name": "حسن",
    "email": "amaryam6674@gmail.com",
    # "birth_date": "1982-07-29 00:00:00",
    # "marital_status": "مجرد",
    "address": "80143 آوا کوچه واحد 560",
    "department": "مدیر عامل",
    "position": "مدیر عامل",
}
d = pd.concat([d, pd.DataFrame([ceo_dic])], ignore_index=True)

# %% [markdown]
# #### field of study / education level (based on position)

# %%
fos_el_dic = {
    # اداره امور حقوقی
    "مدیر عامل": {"fos": {"حقوق": 0.3, "حقوق تجارت": 0.2, "مدیریت": 0.15, "مدیریت بازرگانی": 0.15, "MBA": 0.1, "مالی": 0.05, "اقتصاد": 0.05},
      "el": {"کارشناسی ارشد": 0.55,"دکتری": 0.2, "کارشناسی": 0.2, "پسادکتری": 0.05}},
    "مدیر ارشد حقوقی": {"fos": {"حقوق بین‌الملل": 0.2, "حقوق خصوصی": 0.2, "حقوق عمومی": 0.2, "حقوق کیفری": 0.2, "حقوق تجارت": 0.2},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.2, "کارشناسی": 0.1}},
    "مدیر دپارتمان دعاوی": {"fos": {"حقوق": 0.5, "حقوق بین‌الملل": 0.05, "حقوق خصوصی": 0.2, "حقوق قضایی": 0.1, "حقوق جزا و جرم شناسی": 0.15},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.2, "کارشناسی": 0.1}},
    "مدیر دپارتمان شرکت ها": {"fos": {"حقوق": 0.5, "حقوق تجارت": 0.2, "حقوق شرکت ها": 0.2, "حقوق بازرگانی": 0.1},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.2, "کارشناسی": 0.1}},
    "مدیر دپارتمان قراردداد ها": {"fos": {"حقوق": 0.4, "حقوق تجارت": 0.3, "حقوق قرارداد ها": 0.3},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.2, "کارشناسی": 0.1}},
    "مدیر دپارتمان مالکیت فکری": {"fos": {"حقوق": 0.5, "حقوق مالکیت فکری": 0.5},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.2, "کارشناسی": 0.1}},
    "مدیر دپارتمان تطبیق و انطباق": {"fos": {"حقوق": 0.5, "مدیریت": 0.2, "مالی": 0.15, "اقتصاد": 0.15},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.2, "کارشناسی": 0.1}},
    "مدیر دپارتمان حقوق کار ": {"fos": {"حقوق": 0.5, "حقوق کار": 0.5},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.2, "کارشناسی": 0.1}},
    "مدیر دپارتمان حقوق مالیاتی": {"fos": {"حقوق": 0.25, "حقوق مالیاتی": 0.25, "مالی": 0.25, "حسابداری": 0.25},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.2, "کارشناسی": 0.1}},
    "مدیر دپارتمان تحقیقات حقوقی": {"fos": {"حقوق": 0.5, "مطالعات حقوقی": 0.5},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.2, "کارشناسی": 0.1}},
    "مدیر دپارتمان مالی": {"fos": {"حقوق": 0.4, "حقوق مالیاتی": 0.3, "مالی": 0.3},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.2, "کارشناسی": 0.1}},
    "مدیر دپارتمان منابع انسانی": {"fos": {"مدیریت منابع انسانی": 0.35, "اقتصاد": 0.3, "روان‌شناسی": 0.35},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.2, "کارشناسی": 0.1}},
    "مدیر دپارتمان فناوری اطلاعات": {"fos": {"فناوری اطلاعات": 0.7, "مهندسی کامپیوتر": 0.3},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.2, "کارشناسی": 0.1}},
    "مدیر دپارتمان اداری": {"fos": {"مدیریت دولتی": 0.5, "مدیریت بازرگانی": 0.5},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.2, "کارشناسی": 0.1}},
    "مدیر دپارتمان توسعه کسب و کار": {"fos": {"بازاریابی": 0.5, "مدیریت بازرگانی": 0.5},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.2, "کارشناسی": 0.1}},
    "مدیر دپارتمان حسابرسی داخلی": {"fos": {"مدیریت ریسک": 0.25, "حسابداری": 0.25, "مالی": 0.25, "اقتصاد": 0.25},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.2, "کارشناسی": 0.1}},
    
    # دعاوی
    "وکیل ارشد": {"fos": {"حقوق": 0.5, "حقوق بین‌الملل": 0.05, "حقوق خصوصی": 0.2, "حقوق قضایی": 0.1, "حقوق جزا و جرم شناسی": 0.15},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "وکیل": {"fos": {"حقوق": 0.6, "حقوق خصوصی": 0.15, "حقوق بین‌الملل": 0.1, "حقوق عمومی": 0.05, "حقوق جزا و جرم شناسی": 0.1},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "وکیل جوان": {"fos": {"حقوق": 0.85, "حقوق خصوصی": 0.1, "حقوق جزا و جرم شناسی": 0.05},
      "el": {"کارشناسی ارشد": 0.15, "کارشناسی": 0.85}},
    "دستیار حقوقی - دعاوی": {"fos": {"حقوق": 0.7, "حقوق مطالعاتی": 0.3},
      "el": {"کارشناسی": 0.75, "کاردانی": 0.25}},
    "کارشناسی پرونده": {"fos": {"حقوق": 0.4, "حقوق مطالعاتی": 0.3, "مدیریت": 0.15, "مدیریت دولتی": 0.15},
      "el": {"کارشناسی ارشد": 0.15, "کارشناسی": 0.85}},
    
    # امور شرکتی
    "وکیل ارشد شرکتی": {"fos": {"حقوق": 0.3, "حقوق تجارت": 0.4, "حقوق شرکت ها": 0.2, "حقوق بازرگانی": 0.1},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "وکیل شرکتی": {"fos": {"حقوق": 0.4, "حقوق تجارت": 0.4, "حقوق شرکت ها": 0.2},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "مشاور حقوقی - امور شرکتی ": {"fos": {"حقوق": 0.5, "حقوق تجارت": 0.3, "حقوق بین‌الملل": 0.2},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "دستیار حقوقی - امور شرکتی": {"fos": {"حقوق": 0.7, "حقوق مطالعاتی": 0.3},
      "el": {"کارشناسی": 0.75, "کاردانی": 0.25}},
    
    # قرارداد ها
    "متخصص ارشد قرارداد ها": {"fos": {"حقوق": 0.2, "حقوق تجارت": 0.3, "حقوق قرارداد ها": 0.5},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "متخصص قرارداد ها": {"fos": {"حقوق": 0.2, "حقوق تجارت": 0.3, "حقوق قرارداد ها": 0.5},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "بازبین قرارداد ها": {"fos": {"حقوق": 0.6, "حقوق قرارداد ها": 0.4},
      "el": {"کارشناسی ارشد": 0.5, "کارشناسی": 0.5}},
    "دستیار حقوقی - قرارداد ها": {"fos": {"حقوق": 0.7, "حقوق مطالعاتی": 0.3},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    
    # مالکیت فکری
    "وکیل ثبت اختراع": {"fos": {"حقوق": 0.3, "حقوق مالکیت فکری": 0.5, "مهندسی کامپیوتر + حقوق": 0.1, "مهندسی برق + حقوق": 0.1},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "وکیل علائم تجاری": {"fos": {"حقوق": 0.5, "حقوق مالکیت فکری": 0.5},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "متخصص مالکیت فکری": {"fos": {"حقوق": 0.4, "حقوق مالکیت فکری": 0.6},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "دستیار حقوقی - ماللکیت فکری": {"fos": {"حقوق": 0.7, "حقوق مطالعاتی": 0.3},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    
    # انطباق و تطبیق
    "افسر انطباق": {"fos": {"حقوق": 0.4, "مدیریت بازرگانی": 0.25, "مالی": 0.2, "اقتصاد": 0.15},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "تحلیلگر ریسک": {"fos": {"مالی": 0.4, "اقتصاد": 0.3, "آمار": 0.2, "مدیریت ریسک": 0.1},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "متخصص مقررات": {"fos": {"حقوق": 0.6, "مدیریت دولتی": 0.25, "علوم سیاسی": 0.15},
      "el": {"کارشناسی ارشد": 0.5, "کارشناسی": 0.5}},
    "حسابرس": {"fos": {"حسابداری": 0.6, "مالی": 0.3, "اقتصاد": 0.1},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    
    # کار و اشتغال
    "وکیل ارشد کار": {"fos": {"حقوق": 0.5, "حقوق کار": 0.3, " حقوق خصوصی": 0.15, "حقوق عمومی": 0.05},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "وکیل کار": {"fos": {"حقوق": 0.6, "حقوق کار": 0.25, " حقوق خصوصی": 0.15},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "مشاور حقوقی منابع انسانی": {"fos": {"حقوق": 0.45, "حقوق کار": 0.3, "مدیریت منابع انسانی": 0.15, "مدیریت": 0.1},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "دستیار حقوقی - کار و اشتغال": {"fos": {"حقوق": 0.7, "حقوق مطالعاتی": 0.3},
      "el": {"کارشناسی": 0.75, "کاردانی": 0.25}},
    
    # مالیات
    "وکیل ارشد مالیاتی": {"fos": {"حقوق مالیاتی": 0.45, "حقوق": 0.3, "حسابداری": 0.15, "مالی": 0.1},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "وکیل مالیاتی": {"fos": {"حقوق مالیاتی": 0.45, "حقوق": 0.35, "مالی": 0.2},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "مشاور مالیاتی": {"fos": {"حسابداری": 0.4, "مالی": 0.35, "اقتصاد": 0.15, "حقوق مالیاتی": 0.1},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "دستیار حقوقی - مالیات": {"fos": {"حسابداری": 0.2, "حقوق": 0.6, "مطالعات حقوقی": 0.2},
      "el": {"کارشناسی": 0.75, "کاردانی": 0.25}},
    
    # پژوهش حقوقی
    "پژوهشگر ارشد حقوقی": {"fos": {"حقوق": 0.45, "مطالعات حقوقی": 0.3, "حقوق خصوصی": 0.15, "حقوق بین‌الملل": 0.1},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "پژوهشگر حقوقی": {"fos": {"حقوق": 0.6, "مطالعات حقوقی": 0.25, "حقوق خصوصی": 0.15},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "متخصص مستندسازی": {"fos": {"حقوق": 0.2, "مطالعات حقوقی": 0.2, "علم اطلاعات و دانش‌شناسی": 0.5 , "مدیریت اسناد": 0.1},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "کتابدار": {"fos": {"مطالعات حقوقی": 0.1, "علم اطلاعات و دانش‌شناسی": 0.7 , "مدیریت اسناد": 0.2},
      "el": {"کارشناسی": 0.75, "کاردانی": 0.25}},
    
    # امور مالی
    "مدیر ارشد مالی": {"fos": {"مالی": 0.5, "حسابداری": 0.3, "اقتصاد": 0.1, "MBA": 0.1},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "مدیر حسابداری": {"fos": {"مالی": 0.3, "حسابداری": 0.5, "اقتصاد": 0.2},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "حسابدار ارشد": {"fos": {"مالی": 0.3, "حسابداری": 0.5, "اقتصاد": 0.2},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "حسابدار": {"fos": {"مالی": 0.5, "حسابداری": 0.3, "اقتصاد": 0.2},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "دستیار حسابداری": {"fos": {"مالی": 0.4, "حسابداری": 0.6},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "مدیر حقوق و دستمزد": {"fos": {"حسابداری": 0.4, "مدیریت منابع انسانی": 0.3, "مالی": 0.2, "مدیریت": 0.1},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "متخصص حقوق و دستمزد": {"fos": {"حسابداری": 0.5, "مدیریت منابع انسانی": 0.3, "مالی": 0.2},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "کارمند حقوق و دستمزد": {"fos": {"حسابداری": 0.6, "مدیریت": 0.2, "مالی": 0.2},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "مدیر برنامه ریزی مالی": {"fos": {"حسابداری": 0.5, "اقتصاد": 0.3, "مالی": 0.1, "MBA": 0.1},
      "el": {"کارشناسی": 0.75, "کاردانی": 0.25}},
    "تحلیلگر مالی": {"fos": {"حسابداری": 0.3, "اقتصاد": 0.3, "مالی": 0.2, "آمار": 0.2},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "تحلیلگر بودجه": {"fos": {"حسابداری": 0.3, "اقتصاد": 0.2, "مالی": 0.5},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    
    # منابع انسانی
    "مدیر منابع انسانی": {"fos": {"مدیریت": 0.3, "مدیریت منابع انسانی": 0.4, "روان‌شناسی": 0.2, "MBA": 0.1},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "مدیر جذب و استخدام": {"fos": {"مدیریت": 0.3, "مدیریت منابع انسانی": 0.5, "روان‌شناسی": 0.2},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "کارشناس استخدام": {"fos": {"مدیریت": 0.3, "مدیریت منابع انسانی": 0.5, "روان‌شناسی": 0.2},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "متخصص جذب استعداد": {"fos": {"مدیریت": 0.3, "مدیریت منابع انسانی": 0.5, "روان‌شناسی": 0.2},
      "el": {"کارشناسی": 0.75, "کاردانی": 0.25}},
    "مدیر عملیات منابع انسانی": {"fos": {"مدیریت": 0.5, "مدیریت منابع انسانی": 0.3, "MBA": 0.2},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "متخصص منابع انسانی": {"fos": {"مدیریت": 0.5, "مدیریت منابع انسانی": 0.3, "روان‌شناسی": 0.2},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "هماهنگ‌کننده منابع انسانی": {"fos": {"مدیریت": 0.3, "مدیریت منابع انسانی": 0.5, "روان‌شناسی": 0.2},
      "el": {"کارشناسی": 0.75, "کاردانی": 0.25}},
    "مدیر آموزش": {"fos": {"علوم تربیتی": 0.3, "مدیریت منابع انسانی": 0.4, "روان‌شناسی": 0.3},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "مربی": {"fos": {"علوم تربیتی": 0.5, "مدیریت منابع انسانی": 0.3, "روان‌شناسی": 0.2},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "متخصص یادگیری": {"fos": {"علوم تربیتی": 0.4, "مدیریت منابع انسانی": 0.3, "روان‌شناسی": 0.3},
      "el": {"کارشناسی": 0.75, "کاردانی": 0.25}},
    
    # فناوری اطلاعات
    "مدیر فناوری اطلاعات": {"fos": {"مهندسی کامپیوتر": 0.4, "علوم کامپیوتر": 0.3, "فناوری اطلاعات": 0.2, "MBA": 0.1},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "مدیر زیرساخت": {"fos": {"فناوری اطلاعات": 0.4, "مهندسی کامپیوتر": 0.3, "مهندسی شبکه": 0.3},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "مدیر سیستم": {"fos": {"فناوری اطلاعات": 0.7, "مهندسی کامپیوتر": 0.3},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "مهندس شبکه": {"fos": {"مهندسی کامپیوتر": 0.3, "مهندسی شبکه": 0.7},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "متخصص پشتیبانی فنی": {"fos": {"مهندسی کامپیوتر": 0.5, "علوم کامپیوتر": 0.3, "فناوری اطلاعات": 0.2},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "مدیر نرم‌افزار": {"fos": {"مهندسی کامپیوتر": 0.3, "علوم کامپیوتر": 0.4, "مهندسی نرم‌افزار": 0.3},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "توسعه‌دهنده بک‌اند": {"fos": {"مهندسی کامپیوتر": 0.3, "علوم کامپیوتر": 0.3, "مهندسی نرم‌افزار": 0.4},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "توسعه‌دهنده فرانت‌اند": {"fos": {"فناوری اطلاعات": 0.3, "علوم کامپیوتر": 0.5, "مهندسی نرم‌افزار": 0.2},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "مهندس تضمین کیفیت": {"fos": {"فناوری اطلاعات": 0.5, "علوم کامپیوتر": 0.3, "مهندسی نرم‌افزار": 0.2},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "مدیر پایگاه داده": {"fos": {"مهندسی کامپیوتر": 0.3, "علوم کامپیوتر": 0.4, "فناوری اطلاعات": 0.3},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "مدیر امنیت": {"fos": {"امنیت سایبری": 0.5, "علوم کامپیوتر": 0.3, "فناوری اطلاعات": 0.2},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "تحلیلگر امنیت": {"fos": {"امنیت سایبری": 0.5, "علوم کامپیوتر": 0.2, "فناوری اطلاعات": 0.3},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "متخصص مرکز عملیات امنیت": {"fos": {"امنیت سایبری": 0.6, "علوم کامپیوتر": 0.2, "فناوری اطلاعات": 0.2},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    
    # اداری
    "مدیر اداری": {"fos": {"مدیریت": 0.5, "مدیریت دولتی": 0.3, "مدیریت بازرگانی": 0.2},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "مدیر دفتر": {"fos": {"مدیریت": 0.5, "مدیریت دولتی": 0.3, "مدیریت بازرگانی": 0.2},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "دستیار اجرایی": {"fos": {"مدیریت": 0.3, "زبان انگلیسی": 0.15, "مدیریت بازرگانی": 0.2, "روابط عمومی": 0.35},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "منشی": {"fos": {"مدیریت": 0.4, "روابط عمومی": 0.3, "امور دفتری": 0.3},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "کارشناس تدارکات": {"fos": {"مدیریت زنجیره تامین": 0.3, "مدیریت صنعتی": 0.3, "مدیریت بازرگانی": 0.4},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "کارمند اداری": {"fos": {"مدیریت": 0.4, "مدیریت دولتی": 0.3, "امور دفتری": 0.15, "حسابداری": 0.15},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    
    # توسعه کسب و کار
    "مدیر توسعه کسب‌وکار": {"fos": {"مدیریت بازرگانی": 0.4, "بازاریابی": 0.2, "اقتصاد": 0.1, "MBA": 0.3},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "سرپرست توسعه کسب‌وکار": {"fos": {"مدیریت بازرگانی": 0.5, "بازاریابی": 0.3, "اقتصاد": 0.2},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "متخصص بازاریابی": {"fos": {"مدیریت بازرگانی": 0.3, "بازاریابی": 0.5, "اقتصاد": 0.2},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "متخصص فروش": {"fos": {"مدیریت بازرگانی": 0.5, "بازاریابی": 0.3, "اقتصاد": 0.2},
      "el": {"کارشناسی": 0.75, "کاردانی": 0.25}},
    "متخصص مدیریت ارتباط با مشتری": {"fos": {"مدیریت بازرگانی": 0.4, "بازاریابی": 0.4, "فناوری اطلاعات": 0.2},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    
    # حسابرسی داخلی
    "مدیر حسابرسی": {"fos": {"حسابداری": 0.5, "مالی": 0.3, "اقتصاد": 0.2},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
    "حسابرس داخلی": {"fos": {"حسابداری": 0.6, "مالی": 0.3, "اقتصاد": 0.1},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "حسابرس انطباق": {"fos": {"حسابداری": 0.4, "مالی": 0.3, "حقوق": 0.3},
      "el": {"کارشناسی ارشد": 0.35, "کارشناسی": 0.65}},
    "افسر ریسک": {"fos": {"مدیریت ریسک": 0.4, "مالی": 0.3, "اقتصاد": 0.2, "آمار": 0.1},
      "el": {"کارشناسی ارشد": 0.7, "دکتری": 0.25, "کارشناسی": 0.05}},
}
field_of_study = []
education_level = []

for position in d["position"]:

    fos_el = fos_el_dic[position]

    fos_choices = list(fos_el["fos"].keys())
    fos_probs = list(fos_el["fos"].values())
    el_choices = list(fos_el["el"].keys())
    el_probs = list(fos_el["el"].values())

    field_of_study.append(
        np.random.choice(fos_choices, p=fos_probs)
    )
    education_level.append(
        np.random.choice(el_choices, p=el_probs)
    )
        
d_s = pd.DataFrame({"field_of_study": field_of_study, "education_level": education_level})
d =  pd.concat([d, d_s], axis=1)

# %% [markdown]
# #### university

# %%
university = []
uni_list = ["دانشگاه تهران"," دانشگاه شهید بهشتی"," دانشگاه صنعتی شریف", "دانشگاه علامه طباطبایی",
            "دانشگاه تربیت مدرس", "دانشگاه علم و صنعت", "دانشگاه صنعتی امیرکبیر", "دانشگاه فردوسی مشهد",
            "George Washington University", "University of Texas at Austin", "University of Washington",
            "University of Florida", "Arizona State University", "University of Glasgow", "University of Leeds",
            "University of Nottingham", "University of California, Berkeley", "University of Pennsylvania",
            "Cornell University", "Duke University", "University of Michigan", "Northwestern University",
            "King's College London"]

for i in range(number_of_employees + 1):
    university.append(np.random.choice(uni_list))
    
d_s = pd.DataFrame({"university": university})
d = pd.concat([d, d_s], axis=1)

# %% [markdown]
# ### birth date / marital status

# %%
date = np.empty(number_of_employees + 1 , dtype='U10')
marital_status = np.empty(number_of_employees + 1 , dtype='U10')
l1 = ["مدیر ارشد حقوقی", "مدیر دپارتمان دعاوی", "مدیر دپارتمان شرکت ها", 
      "مدیر دپارتمان قراردداد ها", "مدیر دپارتمان مالکیت فکری", 
      "مدیر دپارتمان تطبیق و انطباق", "مدیر دپارتمان حقوق کار ", 
      "مدیر دپارتمان حقوق مالیاتی", "مدیر دپارتمان تحقیقات حقوقی", 
      "مدیر دپارتمان مالی", "مدیر دپارتمان منابع انسانی", 
      "مدیر دپارتمان فناوری اطلاعات", "مدیر دپارتمان اداری", 
      "مدیر دپارتمان توسعه کسب و کار", "مدیر دپارتمان حسابرسی داخلی"]
l2 = ["وکیل ارشد", "وکیل", "وکیل ارشد", "وکیل", "وکیل ارشد شرکتی", 
      "وکیل شرکتی", "متخصص ارشد قرارداد ها", "وکیل ثبت اختراع", 
      "وکیل علائم تجاری", "متخصص مالکیت فکری", "افسر انطباق", "تحلیلگر ریسک", 
      "متخصص مقررات", "وکیل ارشد کار", "وکیل ارشد مالیاتی", 
      "پژوهشگر ارشد حقوقی", "مدیر ارشد مالی", "مدیر حسابداری", 
      "حسابدار ارشد", "مدیر حقوق و دستمزد", "متخصص حقوق و دستمزد", 
      "مدیر برنامه ریزی مالی", "مدیر منابع انسانی", "مدیر جذب و استخدام", 
      "متخصص جذب استعداد", "مدیر عملیات منابع انسانی", 
      "هماهنگ‌کننده منابع انسانی", "مدیر آموزش", "مدیر فناوری اطلاعات", 
      "مدیر زیرساخت", "مدیر سیستم", "متخصص پشتیبانی فنی", "مدیر نرم‌افزار", 
      "مهندس تضمین کیفیت", "مدیر پایگاه داده", "مدیر امنیت", 
      "متخصص مرکز عملیات امنیت", "مدیر اداری", "مدیر دفتر", 
      "مدیر توسعه کسب‌وکار", "متخصص بازاریابی", "متخصص فروش", 
      "متخصص مدیریت ارتباط با مشتری", "مدیر حسابرسی", "افسر ریسک", "سرپرست توسعه کسب‌وکار"]
l3 = ["وکیل جوان", "کارشناسی پرونده", "مشاور حقوقی - امور شرکتی ", 
      "متخصص قرارداد ها", "بازبین قرارداد ها", "حسابرس", "وکیل کار", "وکیل مالیاتی",
      "پژوهشگر حقوقی", "متخصص مستندسازی", "حسابدار", "دستیار حسابداری", "تحلیلگر مالی",
      "تحلیلگر بودجه", "کارشناس استخدام", "متخصص منابع انسانی", "مربی", 
      "متخصص یادگیری", "مهندس شبکه", "توسعه‌دهنده بک‌اند", "توسعه‌دهنده فرانت‌اند",
      "تحلیلگر امنیت", "دستیار اجرایی", "منشی", "کارشناس تدارکات", 
      "کارمند اداری", "حسابرس داخلی", "حسابرس انطباق"
      ]
for i in range(0, 201):
    if d.iloc[i].loc["gender"] == "خانم":
        if d.iloc[i].loc["position"] in l1:
            start_date = datetime.strptime('1966-01-01', '%Y-%m-%d')
            end_date = datetime.strptime('1986-01-01', '%Y-%m-%d')
            delta = (end_date - start_date).days
            date[i] = (start_date + timedelta(days=random.randint(0, delta))).date()
            marital_choice = ["متاهل", "مجرد"]
            marital_status[i] = np.random.choice(marital_choice, p=[0.80, 0.20])
        elif d.iloc[i].loc["position"] in l2:
            start_date = datetime.strptime('1976-01-01', '%Y-%m-%d')
            end_date = datetime.strptime('1996-01-01', '%Y-%m-%d')
            delta = (end_date - start_date).days
            date[i] = (start_date + timedelta(days=random.randint(0, delta))).date()
            marital_choice = ["متاهل", "مجرد"]
            marital_status[i] = np.random.choice(marital_choice, p=[0.65, 0.35])
        else:
            start_date = datetime.strptime('1976-01-01', '%Y-%m-%d')
            end_date = datetime.strptime('1996-01-01', '%Y-%m-%d')
            delta = (end_date - start_date).days
            date[i] = (start_date + timedelta(days=random.randint(0, delta))).date()
            marital_choice = ["متاهل", "مجرد"]
            marital_status[i] = np.random.choice(marital_choice, p=[0.40, 0.60])    
    else:
        if d.iloc[i].loc["position"] in l1:
            start_date = datetime.strptime('1963-01-01', '%Y-%m-%d')
            end_date = datetime.strptime('1984-01-01', '%Y-%m-%d')
            delta = (end_date - start_date).days
            date[i] = (start_date + timedelta(days=random.randint(0, delta))).date()
            marital_choice = ["متاهل", "مجرد"]
            marital_status[i] = np.random.choice(marital_choice, p=[0.95, 0.05])
        elif d.iloc[i].loc["position"] in l2:
            if d.iloc[i].loc["education_level"] == "دکتری":
                end_date = datetime.strptime('1996-01-01', '%Y-%m-%d')
            elif d.iloc[i].loc["education_level"] == "کارشناسی ارشد":
                end_date = datetime.strptime('1998-01-01', '%Y-%m-%d')
            else:
                end_date = datetime.strptime('2000-01-01', '%Y-%m-%d')
            start_date = datetime.strptime('1976-01-01', '%Y-%m-%d')
            delta = (end_date - start_date).days
            date[i] = (start_date + timedelta(days=random.randint(0, delta))).date()
            marital_choice = ["متاهل", "مجرد"]
            marital_status[i] = np.random.choice(marital_choice, p=[0.70, 0.30])
        else:
            if d.iloc[i].loc["education_level"] == "دکتری":
                end_date = datetime.strptime('1997-01-01', '%Y-%m-%d')
            elif d.iloc[i].loc["education_level"] == "کارشناسی ارشد":
                end_date = datetime.strptime('1999-01-01', '%Y-%m-%d')
            elif d.iloc[i].loc["education_level"] == "کارشناسی":
                end_date = datetime.strptime('2000-01-01', '%Y-%m-%d')
            else:
                end_date = datetime.strptime('2002-01-01', '%Y-%m-%d')
            start_date = datetime.strptime('1976-01-01', '%Y-%m-%d')
            delta = (end_date - start_date).days
            date[i] = (start_date + timedelta(days=random.randint(0, delta))).date()
            marital_choice = ["متاهل", "مجرد"]
            marital_status[i] = np.random.choice(marital_choice, p=[0.40, 0.60])
            

for i in range(201, number_of_employees + 1):
    if d.iloc[i].loc["gender"] == "خانم":
        if d.iloc[i].loc["position"] in l1:
            start_date = datetime.strptime('1976-01-01', '%Y-%m-%d')
            end_date = datetime.strptime('1989-01-01', '%Y-%m-%d')
            delta = (end_date - start_date).days
            date[i] = (start_date + timedelta(days=random.randint(0, delta))).date()
            marital_choice = ["متاهل", "مجرد"]
            marital_status[i] = np.random.choice(marital_choice, p=[0.70, 0.30])
        elif d.iloc[i].loc["position"] in l2:
            start_date = datetime.strptime('1978-01-01', '%Y-%m-%d')
            end_date = datetime.strptime('1997-01-01', '%Y-%m-%d')
            delta = (end_date - start_date).days
            date[i] = (start_date + timedelta(days=random.randint(0, delta))).date()
            marital_choice = ["متاهل", "مجرد"]
            marital_status[i] = np.random.choice(marital_choice, p=[0.45, 0.55])
        else:
            start_date = datetime.strptime('1979-01-01', '%Y-%m-%d')
            end_date = datetime.strptime('1997-01-01', '%Y-%m-%d')
            delta = (end_date - start_date).days
            date[i] = (start_date + timedelta(days=random.randint(0, delta))).date()
            marital_choice = ["متاهل", "مجرد"]
            marital_status[i] = np.random.choice(marital_choice, p=[0.70, 0.30])    
    else:
        if d.iloc[i].loc["position"] in l1:
            start_date = datetime.strptime('1970-01-01', '%Y-%m-%d')
            end_date = datetime.strptime('1990-01-01', '%Y-%m-%d')
            delta = (end_date - start_date).days
            date[i] = (start_date + timedelta(days=random.randint(0, delta))).date()
            marital_choice = ["متاهل", "مجرد"]
            marital_status[i] = np.random.choice(marital_choice, p=[0.97, 0.03])
        elif d.iloc[i].loc["position"] in l2:
            start_date = datetime.strptime('1978-01-01', '%Y-%m-%d')
            end_date = datetime.strptime('1997-01-01', '%Y-%m-%d')
            delta = (end_date - start_date).days
            date[i] = (start_date + timedelta(days=random.randint(0, delta))).date()
            marital_choice = ["متاهل", "مجرد"]
            marital_status[i] = np.random.choice(marital_choice, p=[0.75, 0.25])
        else:
            if d.iloc[i].loc["education_level"] == "دکتری":
                end_date = datetime.strptime('1997-01-01', '%Y-%m-%d')
            elif d.iloc[i].loc["education_level"] == "کارشناسی ارشد":
                end_date = datetime.strptime('1999-01-01', '%Y-%m-%d')
            else:
                end_date = datetime.strptime('2000-01-01', '%Y-%m-%d')
            start_date = datetime.strptime('1970-01-01', '%Y-%m-%d')
            delta = (end_date - start_date).days
            date[i] = (start_date + timedelta(days=random.randint(0, delta))).date()
            marital_choice = ["متاهل", "مجرد"]
            marital_status[i] = np.random.choice(marital_choice, p=[0.60, 0.40])

d["birth_date"] = date
d["marital_status"] = marital_status

# %% [markdown]
# ### graduation year

# %%
graduation_year = np.empty(number_of_employees + 1 , dtype="int16")
l_one = [range(0, 42), range(78, 98), range(132, 156), range(276, 299), range(345, 378), range(425, 451)]
l_two = [range(42, 63), range(100, 132), range(180, 213), range(299, 332), range(389, 425)]
for i in range(number_of_employees + 1):
    if i in l_one:
        bd_year = datetime.strptime(d.iloc[i].loc["birth_date"], "%Y-%m-%d").year
        el = d.iloc[i].loc["education_level"]
        age = 2026 - bd_year 
        if el == "دکتری":
            if age >= 36:
                rand_year = np.random.randint(28, 36)
                graduation_year[i] = rand_year + bd_year
            else:
                rand_year = np.random.randint(28, 2026 - bd_year)
                graduation_year[i] = rand_year + bd_year
        elif el == "کارشناسی ارشد":
            if age >= 30:
                rand_year = np.random.randint(24, 30)
                graduation_year[i] = rand_year + bd_year
            else:
                rand_year = np.random.randint(24, 2026 - bd_year)
                graduation_year[i] = rand_year + bd_year
        elif el == "کارشناسی":
            if age >= 28:
                rand_year = np.random.randint(22, 28)
                graduation_year[i] = rand_year + bd_year
            else:
                rand_year = np.random.randint(22, 2026 - bd_year)
                graduation_year[i] = rand_year + bd_year
        else:
            if age >= 24:
                rand_year = np.random.randint(20, 24)
                graduation_year[i] = rand_year + bd_year
            else:
                rand_year = np.random.randint(20, 2026 - bd_year)
                graduation_year[i] = rand_year + bd_year
    elif i in l_two:
        bd_year = datetime.strptime(d.iloc[i].loc["birth_date"], "%Y-%m-%d").year
        el = d.iloc[i].loc["education_level"]
        age = 2026 - bd_year 
        if el == "دکتری":
            if age >= 38:
                rand_year = np.random.normal((28 + 38) / 2, (38 - 28) / 4)
                rand_year_clip = np.clip(rand_year, 28, 38)
                graduation_year[i] = rand_year_clip + bd_year
            else:
                rand_year = np.random.normal((28 + 2026 - bd_year) / 2, (2026 - bd_year - 28) / 4)
                rand_year_clip = np.clip(rand_year, 28, 2026 - bd_year)
                graduation_year[i] = rand_year_clip + bd_year
        elif el == "کارشناسی ارشد":
            if age >= 32:
                rand_year = np.random.normal((24 + 32) / 2, (32 - 24) / 4)
                rand_year_clip = np.clip(rand_year, 24, 32)
                graduation_year[i] = rand_year_clip + bd_year
            else:
                rand_year = np.random.normal((24 + 2026 - bd_year) / 2, (2026 - bd_year - 24) / 4)
                rand_year_clip = np.clip(rand_year, 24, 2026 - bd_year)
                graduation_year[i] = rand_year_clip + bd_year
        elif el == "کارشناسی":
            if age >= 30:
                rand_year = np.random.normal((22 + 30) / 2, (30 - 22) / 4)
                rand_year_clip = np.clip(rand_year, 22, 30)
                graduation_year[i] = rand_year_clip + bd_year
            else:
                rand_year = np.random.normal((22 + 2026 - bd_year) / 2, (2026 - bd_year - 22) / 4)
                rand_year_clip = np.clip(rand_year, 22, 2026 - bd_year)
                graduation_year[i] = rand_year_clip + bd_year
        else:
            if age >= 26:
                rand_year = np.random.normal((20 + 26) / 2, (26 - 20) / 4)
                rand_year_clip = np.clip(rand_year, 20, 26)
                graduation_year[i] = rand_year_clip + bd_year
            else:
                rand_year = np.random.normal((20 + 2026 - bd_year) / 2, (2026 - bd_year - 20) / 4)
                rand_year_clip = np.clip(rand_year, 20, 2026 - bd_year)
                graduation_year[i] = rand_year_clip + bd_year
    else:
        bd_year = datetime.strptime(d.iloc[i].loc["birth_date"], "%Y-%m-%d").year
        el = d.iloc[i].loc["education_level"]
        age = 2026 - bd_year 
        if el == "دکتری":
            if age >= 40:
                rand_year = np.random.exponential(scale=(40 - 28)/5) + 28
                rand_year_clip = np.clip(rand_year, 28, 40)
                graduation_year[i] = rand_year + bd_year
            else:
                rand_year = np.random.exponential(scale=(2026 - bd_year - 28)/5) + 28
                rand_year_clip = np.clip(rand_year, 28, 2026 - bd_year)
                graduation_year[i] = rand_year + bd_year
        elif el == "کارشناسی ارشد":
            if age >= 33:
                rand_year = np.random.exponential(scale=(33 - 24)/5) + 24
                rand_year_clip = np.clip(rand_year, 24, 33)
                graduation_year[i] = rand_year + bd_year
            else:
                rand_year = np.random.exponential(scale=(2026 - bd_year - 24)/5) + 24
                rand_year_clip = np.clip(rand_year, 24, 2026 - bd_year)
                graduation_year[i] = rand_year + bd_year
        elif el == "کارشناسی":
            if age >= 28:
                rand_year = np.random.exponential(scale=(28 - 22)/5) + 22
                rand_year_clip = np.clip(rand_year, 22, 28)
                graduation_year[i] = rand_year + bd_year
            else:
                rand_year = np.random.exponential(scale=(2026 - bd_year - 22)/5) + 22
                rand_year_clip = np.clip(rand_year, 22, 2026 - bd_year)
                graduation_year[i] = rand_year + bd_year
        else:
            if age >= 26:
                rand_year = np.random.exponential(scale=(26 - 20)/5) + 20
                rand_year_clip = np.clip(rand_year, 20, 26)
                graduation_year[i] = rand_year + bd_year
            else:
                rand_year = np.random.exponential(scale=(2026 - bd_year - 20)/5) + 20
                rand_year_clip = np.clip(rand_year, 20, 2026 - bd_year)
                graduation_year[i] = rand_year + bd_year
            
d["graduation_year"] = graduation_year

# %% [markdown]
# ### employee code

# %%
ec = np.empty(number_of_employees + 1, dtype='U10')
for i in range(number_of_employees + 1):
    if i == 0:
        ec[i] = "EMP_000" + "000"
    elif i < 10:
        ec[i] = "EMP_000" + str(i*100)
        print(ec[i])
    elif i < 100:
        ec[i] = "EMP_000" + str(i*10)
    else:
        ec[i] = "EMP_000" + str(i)

d["employee_code"] = ec
# Out:
# EMP_000100
# EMP_000200
# EMP_000300
# EMP_000400
# EMP_000500
# EMP_000600
# EMP_000700
# EMP_000800
# EMP_000900

# %% [markdown]
# ### GPA

# %%
gpa = np.empty(number_of_employees + 1, dtype="float16")
for i in range(number_of_employees + 1):
    el = d.iloc[i].loc["education_level"]
    if d.iloc[i].loc["position"] in l1:
        if el == "دکتری":
            if i < 100:
                gpa[i] = np.random.normal(20, 1) # چهارده میانگینه و 20 اسکیل هست باید اصلاح کنی
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            elif i < 200:
                gpa[i] = np.random.normal(19, 3)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            elif i < 300:
                gpa[i] = np.random.normal(18, 4)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            else:
                gpa[i] = np.random.normal(19, 4)
                if gpa[i] > 20 :
                    gpa[i] = np.clip(gpa[i], 10, 20)
        elif el == "کارشناسی ارشد":
            if i < 100:
                gpa[i] = np.random.normal(18, 7)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            elif i < 200:
                gpa[i] = np.random.normal(19, 7)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            elif i < 300:
                gpa[i] = np.random.normal(19, 4)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            else:
                gpa[i] = np.random.normal(20, 8)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
        elif el == "کارشناسی":
            if i < 100:
                gpa[i] = np.random.normal(17, 3)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            elif i < 200:
                gpa[i] = np.random.normal(18, 4)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            elif i < 300:
                gpa[i] = np.random.normal(17, 9)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            else:
                gpa[i] = np.random.normal(20, 2)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
        else:
            gpa[i] = np.random.normal(17, 2)
            if gpa[i] > 20 or gpa[i] < 10:
                gpa[i] = np.clip(gpa[i], 10, 20)
    else:
        if el == "دکتری":
            if i < 100:
                gpa[i] = np.random.uniform(14, 19)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            elif i < 200:
                gpa[i] = np.random.normal(12, 2)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            elif i < 300:
                gpa[i] = np.random.normal(13, 5)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            else:
                gpa[i] = np.random.uniform(13, 17)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
        elif el == "کارشناسی ارشد":
            if i < 100:
                gpa[i] = np.random.normal(17, 2)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            elif i < 200:
                gpa[i] = np.random.normal(16, 1)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            elif i < 300:
                gpa[i] = np.random.uniform(16, 16)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            else:
                gpa[i] = np.random.normal(19, 2)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
        elif el == "کارشناسی":
            if i < 100:
                gpa[i] = np.random.normal(17, 1)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            elif i < 200:
                gpa[i] = np.random.uniform(16, 19)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            elif i < 300:
                gpa[i] = np.random.normal(17.5, 2.5)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20)
            else:
                gpa[i] = np.random.normal(17, 2)
                if gpa[i] > 20 or gpa[i] < 10:
                    gpa[i] = np.clip(gpa[i], 10, 20) 
        else:
            gpa[i] = np.random.normal(17, 2)
            if gpa[i] > 20 or gpa[i] < 10:
                gpa[i] = np.clip(gpa[i], 10, 20)
            
stepped_gpa = np.empty(number_of_employees + 1, dtype="float16")
for i in range (number_of_employees + 1):
    stepped_gpa[i] = np.round(gpa[i] / 0.05) * 0.05
d["GPA"] = stepped_gpa

# %% [markdown]
# ### years of experience

# %%
yoe_based_pos = {
    "مدیر عامل": range(28, 45),
    "مدیر ارشد حقوقی": range(18, 30),
    
    "مدیر دپارتمان دعاوی": range(12, 25),
    "مدیر دپارتمان شرکت ها": range(12, 25),
    "مدیر دپارتمان قراردداد ها": range(12, 25),
    "مدیر دپارتمان مالکیت فکری": range(12, 25),
    "مدیر دپارتمان تطبیق و انطباق": range(12, 25),
    "مدیر دپارتمان حقوق کار ": range(12, 25),
    "مدیر دپارتمان حقوق مالیاتی": range(12, 25),
    "مدیر دپارتمان تحقیقات حقوقی": range(10, 22),
    "مدیر دپارتمان مالی": range(14, 22),
    "مدیر دپارتمان منابع انسانی": range(10, 22),
    "مدیر دپارتمان فناوری اطلاعات": range(10, 25),
    "مدیر دپارتمان اداری": range(10, 19),
    "مدیر دپارتمان توسعه کسب و کار": range(15, 30),
    "مدیر دپارتمان حسابرسی داخلی": range(12, 30),
    
    "وکیل ارشد": range(8, 20),
    "وکیل": range(3, 12),
    "وکیل جوان": range(0, 5),
    "دستیار حقوقی - دعاوی": range(0, 6),
    "کارشناسی پرونده": range(1, 8),
    
    "وکیل ارشد شرکتی": range(8, 20),
    "وکیل شرکتی": range(3, 12),
    "مشاور حقوقی - امور شرکتی ": range(5, 15),
    "دستیار حقوقی - امور شرکتی": range(0, 6),
    
    "متخصص ارشد قرارداد ها": range(8, 18),
    "متخصص قرارداد ها": range(3, 12),
    "بازبین قرارداد ها": range(2, 10),
    "دستیار حقوقی - قرارداد ها": range(0, 6),
    
    "وکیل ثبت اختراع": range(5, 15),
    "وکیل علائم تجاری": range(5, 15),
    "متخصص مالکیت فکری": range(3, 12),
    "دستیار حقوقی - ماللکیت فکری": range(0, 6),
    
    "افسر انطباق": range(4, 12),
    "تحلیلگر ریسک": range(2, 10),
    "متخصص مقررات": range(3, 12),
    "حسابرس": range(2, 10),
    
    "وکیل ارشد کار": range(8, 20),
    "وکیل کار": range(3, 12),
    "مشاور حقوقی منابع انسانی": range(4, 12),
    "دستیار حقوقی - کار و اشتغال": range(0, 6),
    
    "وکیل ارشد مالیاتی": range(8, 20),
    "وکیل مالیاتی": range(3, 12),
    "مشاور مالیاتی": range(4, 14),
    "دستیار حقوقی - مالیات": range(0, 6),
    
    "پژوهشگر ارشد حقوقی": range(8, 18),
    "پژوهشگر حقوقی": range(2, 10),
    "متخصص مستندسازی": range(2, 10),
    "کتابدار": range(2, 12),
    
    "مدیر ارشد مالی": range(15, 25),
    "مدیر حسابداری": range(10, 20),
    "حسابدار ارشد": range(6, 15),
    "حسابدار": range(2, 10),
    "دستیار حسابداری": range(0, 5),
    "مدیر حقوق و دستمزد": range(8, 18),
    "متخصص حقوق و دستمزد": range(3, 10),
    "کارمند حقوق و دستمزد": range(1, 6),
    "مدیر برنامه ریزی مالی": range(8, 18),
    "تحلیلگر مالی": range(2, 10),
    "تحلیلگر بودجه": range(2, 10),
    
    "مدیر منابع انسانی": range(10, 22),
    "مدیر جذب و استخدام": range(8, 18),
    "کارشناس استخدام": range(2, 8),
    "متخصص جذب استعداد": range(3, 10),
    "مدیر عملیات منابع انسانی": range(8, 18),
    "متخصص منابع انسانی": range(3, 10),
    "هماهنگ‌کننده منابع انسانی": range(1, 7),
    "مدیر آموزش": range(8, 18),
    "مربی": range(2, 10),
    "متخصص یادگیری": range(3, 10),
    
    "مدیر فناوری اطلاعات": range(10, 20),
    "مدیر زیرساخت": range(8, 18),
    "مدیر سیستم": range(7, 15),
    "مهندس شبکه": range(2, 10),
    "متخصص پشتیبانی فنی": range(1, 8),
    "مدیر نرم‌افزار": range(8, 18),
    "توسعه‌دهنده بک‌اند": range(2, 10),
    "توسعه‌دهنده فرانت‌اند": range(2, 8),
    "مهندس تضمین کیفیت": range(2, 10),
    "مدیر پایگاه داده": range(7, 15),
    "مدیر امنیت": range(8, 18),
    "تحلیلگر امنیت": range(2, 10),
    "متخصص مرکز عملیات امنیت": range(2, 10),
    
    "مدیر اداری": range(8, 18), 
    "مدیر دفتر": range(6, 15),
    "دستیار اجرایی": range(2, 10),
    "منشی": range(1, 8),
    "کارشناس تدارکات": range(2, 10),
    "کارمند اداری": range(1, 7),
    
    "مدیر توسعه کسب‌وکار": range(10, 20),
    "سرپرست توسعه کسب‌وکار": range(6, 15),
    "متخصص بازاریابی": range(2, 10),
    "متخصص فروش": range(2, 10),
    "متخصص مدیریت ارتباط با مشتری": range(2, 10),
    
    "مدیر حسابرسی": range(10, 20),
    "حسابرس داخلی": range(3, 12),
    "حسابرس انطباق": range(3, 12),
    "افسر ریسک": range(4, 14),
}

yoe = np.empty(number_of_employees + 1, dtype="int16")
i = 0
for position in d["position"]:
    yoe_range = yoe_based_pos[position]
    yoe[i] = np.random.choice(yoe_range)
    i += 1
    
d["years_of_experience"] = yoe

# %% [markdown]
# ### hire date

# %%
d['birth_date'] = pd.to_datetime(d['birth_date'])
today = "2026-08-01"
hd = np.empty(number_of_employees + 1, dtype='datetime64[D]')

for i in range(number_of_employees + 1):
    if d.iloc[i].loc["education_level"] == "کاردانی":
        gy = str(d.iloc[i].loc["graduation_year"]) + "-01-01"
        hd_possible = pd.date_range(start=gy, end=today)
        hd_choosed = np.random.choice(hd_possible)
        hd[i] = hd_choosed
    else:
        start_year = str(int(d.iloc[i].loc["birth_date"].year) + 24)
        start_month = str(d.iloc[i].loc["birth_date"].month)
        if int(start_month) < 10:
            start_month = "0" + start_month
        start_day = str(d.iloc[i].loc["birth_date"].day)
        if int(start_day) < 10:
            start_day = "0" + start_day
        start = start_year + '-' + start_month + '-' + start_day
        hd_possible = pd.date_range(start=start, end=today)
        n = len(hd_possible)
        weights = np.exp(-np.linspace(0, 3, n)) 
        weights /= weights.sum()
        hd_choosed = np.random.choice(hd_possible, p=weights)
        hd[i] = hd_choosed
        
d["hire_date"] = hd

# %% [markdown]
# ### years in current position

# %%
yicp = np.empty(number_of_employees + 1, dtype='int16')

for i in range(number_of_employees + 1):
    year_today = 2026
    year_hd = int(d.iloc[i].loc["hire_date"].year)
    max_year = year_today - year_hd
    if (d.iloc[i].loc["position"] in l1) or (d.iloc[i].loc["position"] == "مدیر عامل"):
        peak = 0.7 * max_year
        sigma = 0.15 * max_year
        if not sigma:
            yicp[i] = 0
        else:
            a = (0 - peak) / sigma
            b = (max_year - peak) / sigma
            yicp_choosed = truncnorm.rvs(a, b, loc=peak, scale=sigma)
            yicp_choosed = int(np.round(yicp_choosed))
            yicp[i] = yicp_choosed
    elif d.iloc[i].loc["position"] in l2:
        peak = 0.5 * max_year
        sigma = 0.15 * max_year
        if not sigma:
            yicp[i] = 0
        else:
            a = (0 - peak) / sigma
            b = (max_year - peak) / sigma
            yicp_choosed = truncnorm.rvs(a, b, loc=peak, scale=sigma)
            yicp_choosed = int(np.round(yicp_choosed))
            yicp[i] = yicp_choosed
    else:
        peak = 0.2 * max_year
        sigma = 0.15 * max_year
        if not sigma:
            yicp[i] = 0
        else:
            a = (0 - peak) / sigma
            b = (max_year- peak) / sigma
            yicp_choosed = truncnorm.rvs(a, b, loc=peak, scale=sigma)
            yicp_choosed = int(np.round(yicp_choosed))
            yicp[i] = yicp_choosed
        
d["years_in_current_position"] = yicp

# %% [markdown]
# ### manager code

# %%
man_pos = {
    "مدیر عامل": "nobody",
    "مدیر ارشد حقوقی": "مدیر عامل",

    "مدیر دپارتمان دعاوی": "مدیر ارشد حقوقی",
    "مدیر دپارتمان شرکت ها": "مدیر ارشد حقوقی",
    "مدیر دپارتمان قراردداد ها": "مدیر ارشد حقوقی",
    "مدیر دپارتمان مالکیت فکری": "مدیر ارشد حقوقی",
    "مدیر دپارتمان تطبیق و انطباق": "مدیر ارشد حقوقی",
    "مدیر دپارتمان حقوق کار ": "مدیر ارشد حقوقی",
    "مدیر دپارتمان حقوق مالیاتی": "مدیر ارشد حقوقی",
    "مدیر دپارتمان تحقیقات حقوقی": "مدیر ارشد حقوقی",
    
    "مدیر دپارتمان مالی": "مدیر عامل",
    "مدیر دپارتمان منابع انسانی": "مدیر عامل",
    "مدیر دپارتمان فناوری اطلاعات": "مدیر عامل",
    "مدیر دپارتمان اداری": "مدیر عامل",
    "مدیر دپارتمان توسعه کسب و کار": "مدیر عامل",
    "مدیر دپارتمان حسابرسی داخلی": "مدیر عامل",
    
    
    "وکیل ارشد": "مدیر دپارتمان دعاوی",
    "وکیل": "وکیل ارشد",
    "وکیل جوان": "وکیل",
    "دستیار حقوقی - دعاوی": "وکیل ارشد",
    "کارشناسی پرونده": "وکیل ارشد",

    "وکیل ارشد شرکتی": "مدیر دپارتمان شرکت ها",
    "وکیل شرکتی": "وکیل ارشد شرکتی",
    "مشاور حقوقی - امور شرکتی ": "مدیر دپارتمان شرکت ها",
    "دستیار حقوقی - امور شرکتی": "وکیل ارشد شرکتی",

    "متخصص ارشد قرارداد ها": "مدیر دپارتمان قراردداد ها",
    "متخصص قرارداد ها": "متخصص ارشد قرارداد ها",
    "بازبین قرارداد ها": "متخصص ارشد قرارداد ها",
    "دستیار حقوقی - قرارداد ها": "متخصص قرارداد ها",

    "وکیل ثبت اختراع": "مدیر دپارتمان مالکیت فکری",
    "وکیل علائم تجاری": "مدیر دپارتمان مالکیت فکری",
    "متخصص مالکیت فکری": "مدیر دپارتمان مالکیت فکری",
    "دستیار حقوقی - ماللکیت فکری": "متخصص مالکیت فکری",

    "افسر انطباق": "مدیر دپارتمان تطبیق و انطباق",
    "تحلیلگر ریسک": "مدیر دپارتمان تطبیق و انطباق",
    "متخصص مقررات": "مدیر دپارتمان تطبیق و انطباق",
    "حسابرس": "مدیر دپارتمان تطبیق و انطباق",

    "وکیل ارشد کار": "مدیر دپارتمان حقوق کار ",
    "وکیل کار": "وکیل ارشد کار",
    "مشاور حقوقی منابع انسانی": "مدیر دپارتمان حقوق کار ",
    "دستیار حقوقی - کار و اشتغال": "وکیل ارشد کار",

    "وکیل ارشد مالیاتی": "مدیر دپارتمان حقوق مالیاتی",
    "وکیل مالیاتی": "وکیل ارشد مالیاتی",
    "مشاور مالیاتی": "مدیر دپارتمان حقوق مالیاتی",
    "دستیار حقوقی - مالیات": "وکیل ارشد مالیاتی",

    "پژوهشگر ارشد حقوقی": "مدیر دپارتمان تحقیقات حقوقی",
    "پژوهشگر حقوقی": "پژوهشگر ارشد حقوقی",
    "متخصص مستندسازی": "پژوهشگر ارشد حقوقی",
    "کتابدار": "مدیر دپارتمان تحقیقات حقوقی",

    "مدیر ارشد مالی": "مدیر دپارتمان مالی",
    "مدیر حسابداری": "مدیر ارشد مالی",
    "حسابدار ارشد": "مدیر حسابداری",
    "حسابدار": "حسابدار ارشد",
    "دستیار حسابداری": "حسابدار",
    "مدیر حقوق و دستمزد": "مدیر ارشد مالی",
    "متخصص حقوق و دستمزد": "مدیر حقوق و دستمزد",
    "کارمند حقوق و دستمزد": "متخصص حقوق و دستمزد",
    "مدیر برنامه ریزی مالی": "مدیر ارشد مالی",
    "تحلیلگر مالی": "مدیر برنامه ریزی مالی",
    "تحلیلگر بودجه": "مدیر برنامه ریزی مالی",

    "مدیر منابع انسانی": "مدیر دپارتمان منابع انسانی",
    "مدیر جذب و استخدام": "مدیر منابع انسانی",
    "کارشناس استخدام": "مدیر جذب و استخدام",
    "متخصص جذب استعداد": "مدیر جذب و استخدام",
    "مدیر عملیات منابع انسانی": "مدیر منابع انسانی",
    "متخصص منابع انسانی": "مدیر عملیات منابع انسانی",
    "هماهنگ‌کننده منابع انسانی": "مدیر عملیات منابع انسانی",

    "مدیر آموزش": "مدیر منابع انسانی",
    "مربی": "مدیر آموزش",
    "متخصص یادگیری": "مدیر آموزش",

    "مدیر فناوری اطلاعات": "مدیر دپارتمان فناوری اطلاعات",
    "مدیر زیرساخت": "مدیر فناوری اطلاعات",
    "مدیر سیستم": "مدیر زیرساخت",
    "مهندس شبکه": "مدیر زیرساخت",
    "متخصص پشتیبانی فنی": "مدیر زیرساخت",
    "مدیر نرم‌افزار": "مدیر فناوری اطلاعات",
    "توسعه‌دهنده بک‌اند": "مدیر نرم‌افزار",
    "توسعه‌دهنده فرانت‌اند": "مدیر نرم‌افزار",
    "مهندس تضمین کیفیت": "مدیر نرم‌افزار",
    "مدیر پایگاه داده": "مدیر فناوری اطلاعات",
    "مدیر امنیت": "مدیر فناوری اطلاعات",
    "تحلیلگر امنیت": "مدیر امنیت",
    "متخصص مرکز عملیات امنیت": "مدیر امنیت",

    "مدیر اداری": "مدیر دپارتمان اداری",
    "مدیر دفتر": "مدیر اداری",
    "دستیار اجرایی": "مدیر دفتر",
    "منشی": "مدیر دفتر",
    "کارشناس تدارکات": "مدیر اداری",
    "کارمند اداری": "مدیر اداری",

    "مدیر توسعه کسب‌وکار": "مدیر دپارتمان توسعه کسب و کار",
    "سرپرست توسعه کسب‌وکار": "مدیر توسعه کسب‌وکار",
    "متخصص بازاریابی": "سرپرست توسعه کسب‌وکار",
    "متخصص فروش": "سرپرست توسعه کسب‌وکار",
    "متخصص مدیریت ارتباط با مشتری": "سرپرست توسعه کسب‌وکار",

    "مدیر حسابرسی": "مدیر دپارتمان حسابرسی داخلی",
    "حسابرس داخلی": "مدیر حسابرسی",
    "حسابرس انطباق": "مدیر حسابرسی",
    "افسر ریسک": "مدیر حسابرسی",
}

mc = np.empty(number_of_employees + 1, dtype="U10")

for i in range(number_of_employees + 1):
    if d.iloc[i].loc["position"] == 'مدیر عامل':
        mc[i] = "nobody"
    else:
        manager = man_pos.get(d.iloc[i].loc["position"])
        in_list = d.index[d["position"] == manager].tolist()
        in_choosed = np.random.choice(in_list)
        mc[i] = d.iloc[in_choosed].loc["employee_code"]

d["manager_code"] = mc

# %% [markdown]
# ### employee status

# %%
manager_pos = [
    "مدیر عامل",
    "مدیر ارشد حقوقی",
    "مدیر دپارتمان دعاوی",
    "وکیل ارشد",
    "وکیل",
    "مدیر دپارتمان شرکت ها",
    "وکیل ارشد شرکتی",
    "مدیر دپارتمان قراردداد ها",
    "متخصص ارشد قرارداد ها",
    "متخصص قرارداد ها",
    "مدیر دپارتمان مالکیت فکری",
    "متخصص مالکیت فکری",
    "مدیر دپارتمان تطبیق و انطباق",
    "مدیر دپارتمان حقوق کار ",
    "وکیل ارشد کار",
    "مدیر دپارتمان حقوق مالیاتی",
    "وکیل ارشد مالیاتی",
    "مدیر دپارتمان تحقیقات حقوقی",
    "پژوهشگر ارشد حقوقی",
    "مدیر دپارتمان مالی",
    "مدیر ارشد مالی",
    "مدیر حسابداری",
    "حسابدار ارشد",
    "حسابدار",
    "مدیر ارشد مالی",
    "مدیر حقوق و دستمزد",
    "متخصص حقوق و دستمزد",
    "مدیر ارشد مالی",
    "مدیر برنامه ریزی مالی",
    "مدیر دپارتمان منابع انسانی",
    "مدیر منابع انسانی",
    "مدیر جذب و استخدام",
    "مدیر منابع انسانی",
    "مدیر عملیات منابع انسانی",
    "مدیر منابع انسانی",
    "مدیر آموزش",
    "مدیر دپارتمان فناوری اطلاعات",
    "مدیر فناوری اطلاعات",
    "مدیر زیرساخت",
    "مدیر فناوری اطلاعات",
    "مدیر نرم‌افزار",
    "مدیر امنیت",
    "مدیر دپارتمان اداری",
    "مدیر اداری",
    "مدیر دفتر",
    "مدیر دپارتمان توسعه کسب و کار",
    "مدیر توسعه کسب‌وکار",
    "سرپرست توسعه کسب‌وکار",
    "مدیر دپارتمان حسابرسی داخلی",
    "مدیر حسابرسی",
]

es = np.empty(number_of_employees + 1, dtype="U10")

not_manager = list(set(d["employee_code"].unique()) - set(d["manager_code"].unique()))
not_manager_mask = d[d["employee_code"].isin(not_manager)]

not_manager_and_manager = not_manager_mask[not_manager_mask["position"].isin(manager_pos)]

for i in range(number_of_employees + 1):
    if d.iloc[i]["employee_code"] in not_manager_and_manager["employee_code"].values:
        status_list = ["فعال", "مرخصی", "ماموریت", "تعلیق", "بازنشسته"]
        p = [0.03, 0.07, 0.15, 0.15, 0.6]
        es[i] = np.random.choice(status_list, p=p)
    else:
        if d.iloc[i]["position"] in l1:
            status_list = ["فعال", "مرخصی", "ماموریت"]
            p = [0.75, 0.02, 0.23]
            es[i] = np.random.choice(status_list, p=p)
        elif d.iloc[i]["position"] in l2:
            status_list = ["فعال", "مرخصی", "ماموریت", "تعلیق"]
            p = [0.8, 0.05, 0.1, 0.05]
            es[i] = np.random.choice(status_list, p=p)
        else:
            status_list = ["فعال", "مرخصی", "تعلیق", "بازنشسته"]
            p = [0.85, 0.06, 0.02, 0.07]
            es[i] = np.random.choice(status_list, p=p)
    
d["employee_status"] = es

# %%
d.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   national_code              451 non-null    str
#  1   phone_number               451 non-null    str
#  2   emergency_contact_phone    451 non-null    str
#  3   emergency_contact_name     451 non-null    str
#  4   first_name                 450 non-null    str
#  5   last_name                  450 non-null    str
#  6   gender                     450 non-null    str
#  7   father_name                450 non-null    str
#  8   email                      450 non-null    str
#  9   address                    451 non-null    str
#  10  position                   451 non-null    str
#  11  department                 451 non-null    str
#  12  field_of_study             451 non-null    str
#  13  education_level            451 non-null    str
# ...

# %%
d
# Out:
# c:\Users\ASUS\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\format.py:1466: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
#     national_code  phone_number emergency_contact_phone  \
# 0      0375547463   09197958903             09109016566
# 1      0377452545   09121737316             09122141672
# 2      0385518283   09126913033             09199669188
# 3      0387107044   09105538182             09197411922
# 4      0378276354   09193982327             09107555613
# ..            ...           ...                     ...
# 446    0385853708   09193783493             09109519475
# 447    0388306336   09102649005             09126873385
# 448    0379750768   09121895580             09109516496
# 449    0374944737   09129965688             09102739502
# 450    0362528876  091277594481             09960857522
#
#          emergency_contact_name first_name   last_name gender father_name  \
# ...
